# %%
import numpy as np 
import math 
import torch.nn as nn 
import torch 
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Dataset definition

# %%
noise=[0,0.05,0.1,0.15,0.2]
toy_ds, labels = make_moons(noise=noise[1])

# %%
plt.scatter(x=toy_ds[:,0], y =toy_ds[:,1], c =labels);

# %%
# Teset set and training set definitions
toy_ds_train, toy_ds_test, labels_train, labels_test =  train_test_split(toy_ds, labels,test_size=0.2)

train_tensor_points = torch.cuda.FloatTensor(toy_ds_train)
train_tensor_labels = torch.cuda.FloatTensor(labels_train).resize(len(labels_train),1)

test_tensor_points = torch.cuda.FloatTensor(toy_ds_test)
test_tensor_labels = torch.cuda.FloatTensor(labels_test).resize(len(labels_test),1)
# Out:
# /home/spaghet/anaconda3/envs/semproject/lib/python3.7/site-packages/torch/tensor.py:447: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")

# %% [markdown]
# # Neural Net Definition

# %%
#Basic Neural Net class
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        
        self.model = nn.Sequential(
            nn.Linear(2,50),
            nn.ReLU(),
            nn.Linear(50,1),
            nn.Sigmoid()
        ) 
        
    def forward(self, x):
        res = self.model(x)
        return res

# %% [markdown]
# # Training

# %%
#Training with toy dataset:

classifier = SimpleNN()

# 1 - Loss definition    
loss = torch.nn.BCELoss()

if torch.cuda.is_available():
    classifier.cuda()
    loss.cuda()
    
#Optimizer definition 
optimizer  = torch.optim.Adam(classifier.parameters())

# %%
epochs=[10,20,50,100,500,2000]
loss_evolution=[]
for i in range(epochs[5]):
    optimizer.zero_grad()
 
    outputs = classifier(train_tensor_points)
    
    loss_i = loss(outputs,train_tensor_labels)
    loss_i.backward()

    optimizer.step()

    loss_evolution.append(loss_i.item())

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Training Loss

# %%
plt.plot(loss_evolution)
plt.title("Loss evolution against epochs")
# Out:
# Text(0.5, 1.0, 'Loss evolution against epochs')

# %% [markdown]
# ## Gradient magnitude

# %%
import generator
# %matplotlib notebook

# %%
trainer = generator.Trainer()
trainer.cuda()
trainer.train()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-cb8baa1c62a9> in <module>
#       1 trainer = generator.Trainer()
#       2 trainer.cuda()
# ----> 3 trainer.train()
#
# ~/Desktop/SemProject/Visualization/generator.py in train(self)
#     137
#     138             self.vis.update(g_loss_evolution,[], gen_output.detach().cpu().clone().numpy())
# --> 139             self.vis.display()
#     140
#     141
#
# ~/Desktop/SemProject/Visualization/visualizer.py in display(self)
#      27         ax_temp.plot(self.g_loss)
#      28
# ---> 29         ax_temp = plt.subplot(gs[0,1])
#      30         ax_temp.plot(self.magnitude)
#      31
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axes/_base.py in cla(self)
#    1108         self.containers = []
#    1109
# -> 1110         self.grid(False)  # Disable grid on init to use rcParameter
#    1111         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1112                   axis=mpl.rcParams['axes.grid.axis'])
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2892             self.xaxis.grid(b, which=which, **kwargs)
#    2893         if axis in ['y', 'both']:
# -> 2894             self.yaxis.grid(b, which=which, **kwargs)
#    2895
#    2896     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1446                 self._gridOnMajor = b
#    1447             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1448                                  **gridkw)
#    1449         self.stale = True
#    1450
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     837                 self._major_tick_kw.update(kwtrans)
#     838                 for tick in self.majorTicks:
# --> 839                     tick._apply_params(**kwtrans)
#     840             if which in ['minor', 'both']:
#     841                 self._minor_tick_kw.update(kwtrans)
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     370             tick_kw['markeredgecolor'] = kw['color']
#     371         self.tick1line.set(**tick_kw)
# --> 372         self.tick2line.set(**tick_kw)
#     373         for k, v in tick_kw.items():
#     374             setattr(self, '_' + k, v)
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1111         if move_color_to_start:
#    1112             kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1113         return self.update(kwargs)
#    1114
#    1115     def findobj(self, match=None, include_self=True):
#
# KeyboardInterrupt:
