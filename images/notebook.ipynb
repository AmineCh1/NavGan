# %%
import matplotlib.pyplot as plt
import generator
import directions
import VAEViz

# %% [markdown]
# # 3 Components
# ## Train
# - Allows for training of a GAN couple.
# ## Directions
# - Visualize extracted directions and their effect with trained GAN.
# ## VAEViz
# - Visualizations in the context of Variational Autoencoders.
#
# We show some examples for each.

# %% [markdown]
# ## Train

# %%
training = generator.Trainer(eps = 10)
training.CUDA()
training.train()
# Out:
# cuda:0
# Preparing video ...
# Done !

# %% [markdown]
# ## Direction

# %%
dir_ = directions.Directions()
# Out:
# (64, 2)

# %%
dir_.plot_eigen_vectors()

# %%
dir_.plot_gen_in_out()

# %%
Vae =VAEViz.VAEViz()
Vae.encoder_decoder_spread(val_index = 1)
# Out:
# (144, 784)
# (144, 784)
# (8, 2)
# [-0.11039381, 0.9938881]

# %%
Vae.decoder_encoder_spread()

# %%
Vae.encoder_output()

# %%
Vae.encoder_decoder_energy()
# Out:
# [-4.016186, -0.43811798]
