# %%
import numpy as np 
import math 
import torch.nn as nn 
import torch 
import matplotlib.pyplot as plt
# import model_skeleton.generator
import directions 
import scipy.linalg as la 
# %matplotlib inline

# %%
direction = directions.Directions()

# %%
direction.plot_eigen_vectors(alpha_ = 0.000000001, steps = 20)
direction.video_eigen()
# Out:
# Preparing video ...
# Done !

# %%
direction.eigenvals
# Out:
# array([293.43298  , 189.94585  , 179.66174  , 107.5205   ,  97.72388  ,
#         70.93485  ,  62.72371  ,  37.382896 ,  25.821098 ,  20.613485 ,
#         14.047118 ,   8.599107 ,   5.5742636,   3.145279 ,   1.2510839,
#          1.1670547], dtype=float32)

# %%
x = range(1,101)
plt.scatter(x,direction.eigenvals)
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-f992047d4126> in <module>
#       1 x = range(1,101)
# ----> 2 plt.scatter(x,direction.eigenvals)
#       3 print(x)
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2893         verts=verts, edgecolors=edgecolors,
#    2894         plotnonfinite=plotnonfinite,
# -> 2895         **({"data": data} if data is not None else {}), **kwargs)
#    2896     sci(__ret)
#    2897     return __ret
#
# ~/anaconda3/envs/semproject/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# ...

# %%
trainer = generator.Trainer(eps=100,batch_size = 64)
trainer.cuda()
trainer.train()
